# %% [markdown]
# # Properties data preprocessing

# %%
import pandas as pd
import numpy as np

df = pd.read_json("../data/property.json")
df.shape
# Out:
# (5, 12014)

# %%
properties_df = df.transpose()
properties_df.head()
# Out:
#                                                                                             name  \
# https://www.domain.com.au/904-265-exhibition-st...  904/265 Exhibition Street Melbourne VIC 3000
# https://www.domain.com.au/210-422-collins-stree...     210/422 Collins Street Melbourne VIC 3000
# https://www.domain.com.au/1902-200-spencer-stre...    1902/200 Spencer Street Melbourne VIC 3000
# https://www.domain.com.au/312b-399-bourke-stree...     312B/399 Bourke Street Melbourne VIC 3000
# https://www.domain.com.au/3313-228-la-trobe-str...   3313/228 La Trobe Street Melbourne VIC 3000
#
#                                                         cost_text  \
# https://www.domain.com.au/904-265-exhibition-st...  $850 Per Week
# https://www.domain.com.au/210-422-collins-stree...  $475 Per Week
# https://www.domain.com.au/1902-200-spencer-stre...        $630 pw
# https://www.domain.com.au/312b-399-bourke-stree...           $450
# https://www.domain.com.au/3313-228-la-trobe-str...           $900
#
#                                                                    coordinates  \
# https://www.domain.com.au/904-265-exhibition-st...  [-37.8095116, 144.9691204]
# https://www.domain.com.au/210-422-collins-stree...  [-37.8170971, 144.9601487]
# https://www.domain.com.au/1902-200-spencer-stre...   [-37.816228, 144.9532465]
# https://www.domain.com.au/312b-399-bourke-stree...  [-37.8147259, 144.9621291]
# https://www.domain.com.au/3313-228-la-trobe-str...   [-37.8096052, 144.962371]
#
#                                                                            rooms  \
# https://www.domain.com.au/904-265-exhibition-st...  [2 Beds, 2 Baths, 1 Parking]
# https://www.domain.com.au/210-422-collins-stree...               [1 Bed, 1 Bath]
# https://www.domain.com.au/1902-200-spencer-stre...   [2 Beds, 1 Bath, 1 Parking]
# https://www.domain.com.au/312b-399-bourke-stree...               [1 Bed, 1 Bath]
# https://www.domain.com.au/3313-228-la-trobe-str...   [2 Beds, 1 Bath, 2 Parking]
#
#                                                                 desc
# https://www.domain.com.au/904-265-exhibition-st...     Darren Krause
# https://www.domain.com.au/210-422-collins-stree...  Annalise Zamparo
# https://www.domain.com.au/1902-200-spencer-stre...        Paola Faba
# https://www.domain.com.au/312b-399-bourke-stree...  Natalie Subotsch
# https://www.domain.com.au/3313-228-la-trobe-str...        Paula Tran

# %%
def extract_rooms(rooms_list):
    beds, baths, parkings = None, None, None
    for item in rooms_list:
        if 'Bed' in item:
            beds = int(item.split(' ')[0])
        elif 'Bath' in item:
            baths = int(item.split(' ')[0])
        elif 'Parking' in item:
            parkings = int(item.split(' ')[0])
    return beds, baths, parkings

# %%
# Applying the function and splitting the results
properties_df['beds'], properties_df['baths'], properties_df['parkings'] = zip(*properties_df['rooms'].apply(lambda x: extract_rooms(x)))

properties_df.drop('rooms', axis=1, inplace=True)

# %%
properties_df.head()
# Out:
#                                                                                             name  \
# https://www.domain.com.au/904-265-exhibition-st...  904/265 Exhibition Street Melbourne VIC 3000
# https://www.domain.com.au/210-422-collins-stree...     210/422 Collins Street Melbourne VIC 3000
# https://www.domain.com.au/1902-200-spencer-stre...    1902/200 Spencer Street Melbourne VIC 3000
# https://www.domain.com.au/312b-399-bourke-stree...     312B/399 Bourke Street Melbourne VIC 3000
# https://www.domain.com.au/3313-228-la-trobe-str...   3313/228 La Trobe Street Melbourne VIC 3000
#
#                                                         cost_text  \
# https://www.domain.com.au/904-265-exhibition-st...  $850 Per Week
# https://www.domain.com.au/210-422-collins-stree...  $475 Per Week
# https://www.domain.com.au/1902-200-spencer-stre...        $630 pw
# https://www.domain.com.au/312b-399-bourke-stree...           $450
# https://www.domain.com.au/3313-228-la-trobe-str...           $900
#
#                                                                    coordinates  \
# https://www.domain.com.au/904-265-exhibition-st...  [-37.8095116, 144.9691204]
# https://www.domain.com.au/210-422-collins-stree...  [-37.8170971, 144.9601487]
# https://www.domain.com.au/1902-200-spencer-stre...   [-37.816228, 144.9532465]
# https://www.domain.com.au/312b-399-bourke-stree...  [-37.8147259, 144.9621291]
# https://www.domain.com.au/3313-228-la-trobe-str...   [-37.8096052, 144.962371]
#
#                                                                 desc  beds  \
# https://www.domain.com.au/904-265-exhibition-st...     Darren Krause   2.0
# https://www.domain.com.au/210-422-collins-stree...  Annalise Zamparo   1.0
# https://www.domain.com.au/1902-200-spencer-stre...        Paola Faba   2.0
# https://www.domain.com.au/312b-399-bourke-stree...  Natalie Subotsch   1.0
# https://www.domain.com.au/3313-228-la-trobe-str...        Paula Tran   2.0
#
#                                                     baths  parkings
# https://www.domain.com.au/904-265-exhibition-st...    2.0       1.0
# https://www.domain.com.au/210-422-collins-stree...    1.0       NaN
# https://www.domain.com.au/1902-200-spencer-stre...    1.0       1.0
# https://www.domain.com.au/312b-399-bourke-stree...    1.0       NaN
# https://www.domain.com.au/3313-228-la-trobe-str...    1.0       2.0

# %%
def convert_to_weekly(price_text):
    try:
        # Identifying common text for different frequencies
        week = ["pw", "PW", "week", "/w", " pw"]
        month = ["pcm", "PCM", "pm", "PM", "mth", "month", "per month"]
        annual = ["p.a", "pa", "annually"]
        
        # Check for range indications
        if " to " in price_text:
            return np.nan

        # Extract the first numerical value for the price, correctly handling commas and decimals
        price = float(re.search(r'(\d+\.\d+|\.\d+|\d+)', price_text.replace(',', '')).group(1))

        
        # Check for frequency and convert to weekly
        if any(ext in price_text.lower() for ext in week):
            return price
        elif any(ext in price_text.lower() for ext in month):
            return price / 4.33
        elif any(ext in price_text.lower() for ext in annual):
            return price / 52
        else:
            return price  # default to weekly if no specific frequency is mentioned
    except:
        return np.nan

# Apply the function to the cost_text column
properties_df['weekly_rent'] = properties_df['cost_text'].apply(convert_to_weekly)

# Create invalid df with rows that have NaN in weekly_rent
invalid_df = properties_df[properties_df['weekly_rent'].isna()]

# Drop these rows from the main dataframe
properties_df = properties_df.dropna(subset=['weekly_rent'])

# %%
import re
import numpy as np

def convert_to_weekly(price_text):
    try:
        # Identifying common text for different frequencies
        week = ["/w", "pw", "PW", "Week", "week", "w.", "w,", "PER WEEK", "/W", "wk", "p.w", "/ WK", "/ WEEK"]
        month = ["pcm", "PCM", "pm", "PM", "mth", "month", "Month", "MONTH", "m.", "m,",]
        annual = ["p.a", "pa", "Annually"]

        # Extract all floating-point numbers from the text
        prices = [float(price.replace(',', '')) for price in re.findall(r'(\d+,\d+\.\d+|\d+\.\d+|\d+)', price_text)]
        # If there's a '/', consider the first part as weekly and the second part as monthly
        weekly_price = prices[0] if prices else np.nan
        monthly_price = prices[1] if len(prices) > 1 else None

        # Check for frequency and convert to weekly
        if any(keyword in price_text for keyword in week) or not any(char.isalpha() for char in price_text):
            return weekly_price
        elif any(keyword in price_text for keyword in month):
            return weekly_price or (monthly_price / 4.33)  # If there's a secondary monthly price, use it.
        elif any(keyword in price_text for keyword in annual):
            return weekly_price / 52  # Convert yearly to weekly
        else:
            # If there are descriptive words without specified frequency, assume it as weekly rent
            descriptions = ["furnished", "unfurnished", "bedroom", "spot", "renovated"]
            if any(desc.lower() in price_text.lower() for desc in descriptions):
                return weekly_price
            return np.nan
    except:
        return np.nan


# Apply the function to the cost_text column
properties_df['weekly_rent'] = properties_df['cost_text'].apply(convert_to_weekly)

# Create invalid df with rows that have NaN in weekly_rent
invalid_df = properties_df[properties_df['weekly_rent'].isna()]

# Drop these rows from the main dataframe
properties_df = properties_df.dropna(subset=['weekly_rent'])

# %%
invalid_df['cost_text'].to_csv("../data/test.csv")

# %%
no_beds = properties_df[properties_df['beds'] < 1]

# %%
no_beds
# Out:
#                                                                                              name  \
# https://www.domain.com.au/2805-220-spencer-stre...     2805/220 Spencer Street Melbourne VIC 3000
# https://www.domain.com.au/100-19-exploration-la...     100/19 Exploration Lane Melbourne VIC 3000
# https://www.domain.com.au/2105s-220-spencer-str...    2105s/220 Spencer Street Melbourne VIC 3000
# https://www.domain.com.au/4206-220-spencer-stre...     4206/220 Spencer Street Melbourne VIC 3000
# https://www.domain.com.au/236-la-trobe-street-m...         236 La Trobe Street Melbourne VIC 3000
# ...                                                                                           ...
# https://www.domain.com.au/128-murray-valley-hig...  128 Murray Valley Highway Yarrawonga VIC 3730
# https://www.domain.com.au/16-echidna-street-loc...          16 Echidna Street Loch Sport VIC 3851
# https://www.domain.com.au/4-10-duiker-court-lan...          4/10 Duiker court Langwarrin VIC 3910
# https://www.domain.com.au/2-52-childers-street-...       2/52 Childers Street Cranbourne VIC 3977
# https://www.domain.com.au/197-hardys-road-toora...              197 HARDYS ROAD Tooradin VIC 3980
#
#                                                                                             cost_text  \
# https://www.domain.com.au/2805-220-spencer-stre...                                      $430 per week
# https://www.domain.com.au/100-19-exploration-la...          FROM $480PW, FURNITURE AND BILLS INCLUDED
# https://www.domain.com.au/2105s-220-spencer-str...                                      $430 Per Week
# https://www.domain.com.au/4206-220-spencer-stre...                                      $430 per week
# https://www.domain.com.au/236-la-trobe-street-m...  Furnished, all inclusive modern studios from $...
# ...                                                                                               ...
# https://www.domain.com.au/128-murray-valley-hig...                                               $280
# https://www.domain.com.au/16-echidna-street-loc...                                      $280 per week
# https://www.domain.com.au/4-10-duiker-court-lan...                                   $1,297 per month
# https://www.domain.com.au/2-52-childers-street-...                                      $320 per week
# https://www.domain.com.au/197-hardys-road-toora...                                               $454
#
#                                                                    coordinates  \
# https://www.domain.com.au/2805-220-spencer-stre...   [-37.815781, 144.9529156]
# https://www.domain.com.au/100-19-exploration-la...  [-37.8089339, 144.9680888]
# https://www.domain.com.au/2105s-220-spencer-str...   [-37.815781, 144.9529156]
# https://www.domain.com.au/4206-220-spencer-stre...   [-37.815781, 144.9529156]
# https://www.domain.com.au/236-la-trobe-street-m...  [-37.8098249, 144.9624192]
# ...                                                                        ...
# https://www.domain.com.au/128-murray-valley-hig...   [-36.020273, 145.9908219]
# https://www.domain.com.au/16-echidna-street-loc...   [-38.037121, 147.5988684]
# https://www.domain.com.au/4-10-duiker-court-lan...  [-38.1406873, 145.1757278]
# https://www.domain.com.au/2-52-childers-street-...    [-38.112789, 145.289034]
# https://www.domain.com.au/197-hardys-road-toora...  [-38.1972789, 145.4104247]
#
#                                                                                                  desc  \
# https://www.domain.com.au/2805-220-spencer-stre...                                         Paula Tran
# https://www.domain.com.au/100-19-exploration-la...                 Exploration Lane Community Manager
# https://www.domain.com.au/2105s-220-spencer-str...                                         Paula Tran
# https://www.domain.com.au/4206-220-spencer-stre...                                         Paula Tran
# https://www.domain.com.au/236-la-trobe-street-m...  nbn® Fibre to the Premises (FTTP) is available...
# ...                                                                                               ...
# https://www.domain.com.au/128-murray-valley-hig...                               * Unverified feature
# https://www.domain.com.au/16-echidna-street-loc...  nbn® Fibre to the Node (FTTN) is available in ...
# https://www.domain.com.au/4-10-duiker-court-lan...                               * Unverified feature
# https://www.domain.com.au/2-52-childers-street-...  Offering the ultimate in first-class accommoda...
# https://www.domain.com.au/197-hardys-road-toora...                                  LAND LEASE ONLY.
#
#                                                     beds  baths  parkings  \
# https://www.domain.com.au/2805-220-spencer-stre...   0.0    1.0       NaN
# https://www.domain.com.au/100-19-exploration-la...   0.0    1.0       NaN
# https://www.domain.com.au/2105s-220-spencer-str...   0.0    1.0       NaN
# https://www.domain.com.au/4206-220-spencer-stre...   0.0    1.0       NaN
# https://www.domain.com.au/236-la-trobe-street-m...   0.0    1.0       NaN
# ...                                                  ...    ...       ...
# https://www.domain.com.au/128-murray-valley-hig...   0.0    2.0       NaN
# https://www.domain.com.au/16-echidna-street-loc...   0.0    1.0       NaN
# https://www.domain.com.au/4-10-duiker-court-lan...   0.0    1.0       NaN
# https://www.domain.com.au/2-52-childers-street-...   0.0    1.0       1.0
# https://www.domain.com.au/197-hardys-road-toora...   0.0    1.0       NaN
#
#                                                     weekly_rent
# https://www.domain.com.au/2805-220-spencer-stre...   430.000000
# https://www.domain.com.au/100-19-exploration-la...   480.000000
# https://www.domain.com.au/2105s-220-spencer-str...   430.000000
# https://www.domain.com.au/4206-220-spencer-stre...   430.000000
# https://www.domain.com.au/236-la-trobe-street-m...   650.000000
# ...                                                         ...
# https://www.domain.com.au/128-murray-valley-hig...   280.000000
# https://www.domain.com.au/16-echidna-street-loc...   280.000000
# https://www.domain.com.au/4-10-duiker-court-lan...   299.538106
# https://www.domain.com.au/2-52-childers-street-...   320.000000
# https://www.domain.com.au/197-hardys-road-toora...   454.000000
#
# [130 rows x 8 columns]
