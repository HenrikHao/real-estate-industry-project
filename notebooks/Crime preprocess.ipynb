# %%
import pandas as pd
import json
import geopandas as gpd
from shapely.geometry import Point

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in /home/jqqian1/.local/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /home/jqqian1/.local/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Your property data
property_metadata = pd.read_csv("../data/raw/properties.csv")

# Convert the coordinates column to a suitable format (assuming it's a string like '[lat, lon]')
property_metadata['coordinates'] = property_metadata['coordinates'].apply(eval)

# Create points and names from the property_metadata
coords = [Point(xy[1], xy[0]) for xy in property_metadata['coordinates']]
names = property_metadata['name'].tolist()

# Convert to GeoDataFrame
property = gpd.GeoDataFrame({'name': names, 'geometry': coords})

# %%
# Assuming property_gdf and victoria_gdf are already defined as per your provided code...
victoria_gdf = gpd.read_file('../data/Statistical_area_level2/victoria.geojson')

# Perform a spatial join
property_SA2 = gpd.sjoin(property, victoria_gdf, how="inner", op="within")
# Out:
# /home/jqqian1/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /tmp/ipykernel_28908/2101387466.py:5: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   property_SA2 = gpd.sjoin(property, victoria_gdf, how="inner", op="within")

# %%
property_SA2
# Out:
#                                                name  \
# 0      904/265 Exhibition Street Melbourne VIC 3000
# 6          2302/17 Spring Street Melbourne VIC 3000
# 12         11/187 Collins Street Melbourne VIC 3000
# 19       1605/68 La Trobe Street Melbourne VIC 3000
# 21         3007/35 Spring Street Melbourne VIC 3000
# ...                                             ...
# 11586    21 Swallowtail Avenue Clyde North VIC 3978
# 11591  18 Flowerbloom Crescent Clyde North VIC 3978
# 11596             19 Anvil Way Clyde North VIC 3978
# 11604     51 Springleaf Avenue Clyde North VIC 3978
# 11605        22 Spartan Avenue Clyde North VIC 3978
#
#                           geometry  index_right SA2_CODE21  \
# 0      POINT (144.96912 -37.80951)          135  206041503
# 6      POINT (144.97440 -37.81475)          135  206041503
# 12     POINT (144.96785 -37.81540)          135  206041503
# 19     POINT (144.96679 -37.80836)          135  206041503
# 21     POINT (144.97400 -37.81417)          135  206041503
# ...                            ...          ...        ...
# 11586  POINT (145.37630 -38.08402)          363  212031555
# 11591  POINT (145.34483 -38.07650)          363  212031555
# 11596  POINT (145.36043 -38.08417)          363  212031555
# 11604  POINT (145.35015 -38.08134)          363  212031555
# 11605  POINT (145.34202 -38.08875)          363  212031555
#
#                  SA2_NAME21 CHG_FLAG21 CHG_LBL21 SA3_CODE21      SA3_NAME21  \
# 0      Melbourne CBD - East          1       New      20604  Melbourne City
# 6      Melbourne CBD - East          1       New      20604  Melbourne City
# 12     Melbourne CBD - East          1       New      20604  Melbourne City
# 19     Melbourne CBD - East          1       New      20604  Melbourne City
# 21     Melbourne CBD - East          1       New      20604  Melbourne City
# ...                     ...        ...       ...        ...             ...
# 11586   Clyde North - North          1       New      21203   Casey - South
# 11591   Clyde North - North          1       New      21203   Casey - South
# 11596   Clyde North - North          1       New      21203   Casey - South
# 11604   Clyde North - North          1       New      21203   Casey - South
# 11605   Clyde North - North          1       New      21203   Casey - South
#
#       SA4_CODE21              SA4_NAME21 GCC_CODE21         GCC_NAME21  \
# 0            206       Melbourne - Inner      2GMEL  Greater Melbourne
# 6            206       Melbourne - Inner      2GMEL  Greater Melbourne
# 12           206       Melbourne - Inner      2GMEL  Greater Melbourne
# 19           206       Melbourne - Inner      2GMEL  Greater Melbourne
# 21           206       Melbourne - Inner      2GMEL  Greater Melbourne
# ...          ...                     ...        ...                ...
# 11586        212  Melbourne - South East      2GMEL  Greater Melbourne
# 11591        212  Melbourne - South East      2GMEL  Greater Melbourne
# 11596        212  Melbourne - South East      2GMEL  Greater Melbourne
# 11604        212  Melbourne - South East      2GMEL  Greater Melbourne
# 11605        212  Melbourne - South East      2GMEL  Greater Melbourne
#
#       STE_CODE21 STE_NAME21 AUS_CODE21 AUS_NAME21  AREASQKM21  \
# 0              2   Victoria        AUS  Australia      0.8020
# 6              2   Victoria        AUS  Australia      0.8020
# 12             2   Victoria        AUS  Australia      0.8020
# 19             2   Victoria        AUS  Australia      0.8020
# 21             2   Victoria        AUS  Australia      0.8020
# ...          ...        ...        ...        ...         ...
# 11586          2   Victoria        AUS  Australia      6.8833
# 11591          2   Victoria        AUS  Australia      6.8833
# 11596          2   Victoria        AUS  Australia      6.8833
# 11604          2   Victoria        AUS  Australia      6.8833
# 11605          2   Victoria        AUS  Australia      6.8833
#
#                                               LOCI_URI21
# 0      http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 6      http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 12     http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 19     http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 21     http://linked.data.gov.au/dataset/asgsed3/SA2/...
# ...                                                  ...
# 11586  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 11591  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 11596  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 11604  http://linked.data.gov.au/dataset/asgsed3/SA2/...
# 11605  http://linked.data.gov.au/dataset/asgsed3/SA2/...
#
# [11674 rows x 19 columns]

# %%
property_SA2['name'] = property_SA2['name'].str[-4:]

# %%
property_SA2 = property_SA2[['name', 'geometry', 'SA2_CODE21', 'SA2_NAME21']]

# %%
property_SA2.rename(columns={'name': 'Postcode'}, inplace=True)
# Out:
# /tmp/ipykernel_28908/2595192371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_SA2.rename(columns={'name': 'Postcode'}, inplace=True)

# %%
property_SA2['Postcode'] = property_SA2['Postcode'].astype('int')
# Out:
# /home/jqqian1/.local/lib/python3.10/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
offence = pd.read_excel("../data/external_SA2/Offence Count.xlsx", sheet_name='Table 03')

# %%
offence_count = offence.groupby('Postcode')['Offence Count'].sum().reset_index()

# %%
crime = pd.merge(property_SA2, offence_count, on='Postcode', how='left')

# %%
crime.to_csv("../data/raw/Offense count by postcode.csv")
